# %% [markdown]
# # Analyzing FEMA's National Flood Insurance Program (NFIP) Data With DuckDB
# Author: Mark Bauer

# %% [markdown]
# # OpenFEMA Dataset: FIMA NFIP Redacted Claims - v2
# Federal Emergency Management Agency (FEMA), OpenFEMA Dataset: FIMA NFIP Redacted Claims - v2. Retrieved from https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2. This product uses the FEMA OpenFEMA API, but is not endorsed by FEMA. The Federal Government or FEMA cannot vouch for the data or analyses derived from these data after the data have been retrieved from the Agency's website(s).
#
# Read more about OpenFEMA's  [Terms and Conditions](https://www.fema.gov/about/openfema/terms-conditions).
#
# **Dataset Description**:
# >This dataset provides details on NFIP claims transactions. It is derived from the NFIP system of record, staged in the NFIP reporting platform and redacted to protect policy holder personally identifiable information.
# >
# >This dataset is not intended to be an official federal report, and should not be considered an official federal report.
#
# **About the National Flood Insurance Program**:
# >Congress passed the National Flood Insurance Act (NFIA), 42 U.S.C. 4001 in 1968, creating the National Flood Insurance Program (NFIP) in order to reduce future flood losses through flood hazard identification, floodplain management, and providing insurance protection. The Department of Housing and Urban Development (HUD) originally administered the NFIP, and Congress subsequently transferred the NFIP to FEMA upon its creation in 1979. FEMA and insurance companies participating in FEMA's Write Your Own (WYO) program offer NFIP insurance coverage for building structures as well as for contents and personal property within the building structures to eligible and insurable properties. The WYO program began in 1983 with NFIP operating under Part B of the NFIA and allows FEMA to authorize private insurance companies to issue the Standard Flood Insurance Policy (SFIP) as FEMA's fiduciary and fiscal agent. FEMA administers NFIP by ensuring insurance applications are processed properly; determining correct premiums; renewing, reforming, and cancelling insurance policies; transferring policies from the seller of the property to the purchaser of the property in certain circumstances; and processing insurance claims.
# >
# >The paid premiums of SFIPs and claims payments for damaged property are processed through the National Flood Insurance Fund (NFIF). NFIF was established by the National Flood Insurance Act of 1968 (42 U.S.C. 4001, et seq.), and is a centralized premium revenue and fee-generated fund that supports NFIP, which holds these U.S. Treasury funds.
# >
# >The Flood Insurance Claims Manual (https://nfipservices.floodsmart.gov/insurance-manuals) provides claims guidance to WYOs, vendors, adjusters, and examiners so that policyholders experience consistent and reliable service. The Manual provides processes for handling claims from the notice of loss to final payment. The NFIP has provided answers to Frequently Asked Questions (FAQs) to assist the public in understanding and navigating the data our program makes available: https://www.fema.gov/sites/default/files/documents/fema_nfip-data-faqs.pdf.
#
# **Data Dictionary**:
# View the data dictionary on OpenFEMA under the [Data Fields](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2) section.
#
# Note: In this notebook, all dollar amounts are reported in nominal terms and have not been adjusted for inflation.

# %%
# import libraries
import duckdb
import pandas as pd

# %%
# reproducibility
# %reload_ext watermark
# %watermark -v -p duckdb,pandas
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# duckdb: 1.0.0
# pandas: 1.5.1

# %%
# list datasets
# %ls data/
# Out:
# FimaNfipClaims.parquet       nfip-data.db
# FimaNfipPolicies.parquet     policies-nyc-year.parquet
# claims-nyc-year.parquet      policies-state-year.parquet
# claims-state-year.parquet    policies.db
# claims.db

# %% [markdown]
# # Redacted Claims: Before Getting Started
# Please note that this dataset provides details on NFIP claims transactions and is ***redacted*** to protect policy holder personally identifiable information. The claim's `latitude` and `longitude` field **should not be used to represent the precise location of the insured building**. From the data dictionary:
#
# >Latitude: **Approximate latitude of the insured building (to 1 decimal place)**. This represents the approximate location of the insured property. The precision has been lessened to ensure individual privacy. This may result in a point location that exists in an incorrect county or state. Use the state and county fields for record aggregation for these dimensions.
# >
# >Longitude: **Approximate longitude of the insured building (to 1 decimal place)**. This represents the approximate location of the insured property. The precision has been lessened to ensure individual privacy. This may result in a point location that exists in an incorrect county or state. Use the state and county fields for record aggregation for these dimensions.
#
# For more information, visit the [Data Dictionary](https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2) and review [Frequently Asked Questions about NFIP Policies and Claims Data](https://nfipservices.floodsmart.gov/frequently-asked-questions-about-nfip-policies-and-claims-data).

# %% [markdown]
# This analysis presents all financial figures in nominal dollars. No adjustments for inflation have been made, meaning that the values reflect the actual dollar amounts at the time of measurement. Additionally, the date and time of data access can be found in the download-data notebook.

# %% [markdown]
# # Create a DuckDB database instance using the Python client

# %%
# %%time

# create a DuckDB database instance
con = duckdb.connect("data/nfip.db")

# create table claims of dataset
con.execute("""
    CREATE OR REPLACE TABLE claims AS
        FROM read_parquet('data/FimaNfipClaims.parquet')
""")

# sanity check
con.sql("""
    SELECT *
    FROM claims
    LIMIT 5
""").show()
# Out:
# ┌──────────────────────┬──────────────────────┬───┬──────────────┬──────────────┬──────────────────────┐
# │ agricultureStructu…  │       asOfDate       │ … │   latitude   │  longitude   │          id          │
# │       boolean        │ timestamp with tim…  │   │ decimal(9,1) │ decimal(9,1) │         uuid         │
# ├──────────────────────┼──────────────────────┼───┼──────────────┼──────────────┼──────────────────────┤
# │ false                │ NULL                 │ … │         39.2 │        -74.6 │ a4edd1e3-a2cc-4ea7…  │
# │ false                │ NULL                 │ … │         29.9 │        -95.3 │ 5fa56e50-7923-44f3…  │
# │ false                │ NULL                 │ … │         40.0 │        -74.1 │ ee43a296-bc2b-4b49…  │
# │ false                │ NULL                 │ … │         29.9 │        -95.4 │ 2d96f6b6-d33b-4eda…  │
# │ false                │ NULL                 │ … │         26.4 │        -81.9 │ 37577287-ba9f-4cea…  │
# ├──────────────────────┴──────────────────────┴───┴──────────────┴──────────────┴──────────────────────┤
# │ 5 rows                                                                          73 columns (5 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# CPU times: user 29.3 s, sys: 2.37 s, total: 31.7 s
# Wall time: 4.67 s

# %%
# list tables and schemas
con.sql("SHOW ALL TABLES").df()
# Out:
#   database schema    name                                       column_names  \
# 0     nfip   main  claims  [agricultureStructureIndicator, asOfDate, base...
#
#                                         column_types  temporary
# 0  [BOOLEAN, TIMESTAMP WITH TIME ZONE, SMALLINT, ...      False

# %%
# count of rows
con.sql("""
    SELECT COUNT(*) AS count_rows
    FROM claims
""")
# Out:
# ┌────────────┐
# │ count_rows │
# │   int64    │
# ├────────────┤
# │    2712269 │
# └────────────┘

# %%
# count of columns
con.sql("""
    SELECT COUNT(column_name) AS count_columns
    FROM (DESCRIBE FROM claims)
""")
# Out:
# ┌───────────────┐
# │ count_columns │
# │     int64     │
# ├───────────────┤
# │            73 │
# └───────────────┘

# %%
# last refreshed
con.sql("""
    SELECT asOfDate
    FROM claims
    ORDER BY asOfDate DESC
    LIMIT 1
""")
# Out:
# ┌───────────────────────────────┐
# │           asOfDate            │
# │   timestamp with time zone    │
# ├───────────────────────────────┤
# │ 2025-05-09 10:37:51.032136-04 │
# └───────────────────────────────┘

# %% [markdown]
# # Examine Dataset

# %% [markdown]
# ## Column Info

# %%
# examine column datatypes
con.sql("""
    SELECT
        column_name,
        column_type
    FROM (DESCRIBE claims)
""").show(max_rows=80)
# Out:
# ┌────────────────────────────────────────────┬──────────────────────────┐
# │                column_name                 │       column_type        │
# │                  varchar                   │         varchar          │
# ├────────────────────────────────────────────┼──────────────────────────┤
# │ agricultureStructureIndicator              │ BOOLEAN                  │
# │ asOfDate                                   │ TIMESTAMP WITH TIME ZONE │
# │ basementEnclosureCrawlspaceType            │ SMALLINT                 │
# │ policyCount                                │ SMALLINT                 │
# │ crsClassificationCode                      │ SMALLINT                 │
# │ dateOfLoss                                 │ DATE                     │
# │ elevatedBuildingIndicator                  │ BOOLEAN                  │
# │ elevationCertificateIndicator              │ VARCHAR                  │
# │ elevationDifference                        │ DECIMAL(6,1)             │
# │ baseFloodElevation                         │ DECIMAL(6,1)             │
# │ ratedFloodZone                             │ VARCHAR                  │
# │ houseWorship                               │ BOOLEAN                  │
# │ locationOfContents                         │ SMALLINT                 │
# │ lowestAdjacentGrade                        │ DECIMAL(6,1)             │
# │ lowestFloorElevation                       │ DECIMAL(6,1)             │
# │ numberOfFloorsInTheInsuredBuilding         │ SMALLINT                 │
# │ nonProfitIndicator                         │ BOOLEAN                  │
# │ obstructionType                            │ SMALLINT                 │
# │ occupancyType                              │ SMALLINT                 │
# │ originalConstructionDate                   │ DATE                     │
# │ originalNBDate                             │ DATE                     │
# │ amountPaidOnBuildingClaim                  │ DECIMAL(12,2)            │
# │ amountPaidOnContentsClaim                  │ DECIMAL(12,2)            │
# │ amountPaidOnIncreasedCostOfComplianceClaim │ DECIMAL(12,2)            │
# │ postFIRMConstructionIndicator              │ BOOLEAN                  │
# │ rateMethod                                 │ VARCHAR                  │
# │ smallBusinessIndicatorBuilding             │ BOOLEAN                  │
# │ totalBuildingInsuranceCoverage             │ BIGINT                   │
# │ totalContentsInsuranceCoverage             │ BIGINT                   │
# │ yearOfLoss                                 │ SMALLINT                 │
# │ primaryResidenceIndicator                  │ BOOLEAN                  │
# │ buildingDamageAmount                       │ BIGINT                   │
# │ buildingDeductibleCode                     │ VARCHAR                  │
# │ netBuildingPaymentAmount                   │ DECIMAL(12,2)            │
# │ buildingPropertyValue                      │ BIGINT                   │
# │ causeOfDamage                              │ VARCHAR                  │
# │ condominiumCoverageTypeCode                │ VARCHAR                  │
# │ contentsDamageAmount                       │ BIGINT                   │
# │ contentsDeductibleCode                     │ VARCHAR                  │
# │ netContentsPaymentAmount                   │ DECIMAL(12,2)            │
# │ contentsPropertyValue                      │ BIGINT                   │
# │ disasterAssistanceCoverageRequired         │ SMALLINT                 │
# │ eventDesignationNumber                     │ VARCHAR                  │
# │ ficoNumber                                 │ SMALLINT                 │
# │ floodCharacteristicsIndicator              │ SMALLINT                 │
# │ floodWaterDuration                         │ SMALLINT                 │
# │ floodproofedIndicator                      │ BOOLEAN                  │
# │ floodEvent                                 │ VARCHAR                  │
# │ iccCoverage                                │ INTEGER                  │
# │ netIccPaymentAmount                        │ DECIMAL(8,2)             │
# │ nfipRatedCommunityNumber                   │ VARCHAR                  │
# │ nfipCommunityNumberCurrent                 │ VARCHAR                  │
# │ nfipCommunityName                          │ VARCHAR                  │
# │ nonPaymentReasonContents                   │ VARCHAR                  │
# │ nonPaymentReasonBuilding                   │ VARCHAR                  │
# │ numberOfUnits                              │ INTEGER                  │
# │ buildingReplacementCost                    │ BIGINT                   │
# │ contentsReplacementCost                    │ BIGINT                   │
# │ replacementCostBasis                       │ VARCHAR                  │
# │ stateOwnedIndicator                        │ BOOLEAN                  │
# │ waterDepth                                 │ SMALLINT                 │
# │ floodZoneCurrent                           │ VARCHAR                  │
# │ buildingDescriptionCode                    │ SMALLINT                 │
# │ rentalPropertyIndicator                    │ BOOLEAN                  │
# │ state                                      │ VARCHAR                  │
# │ reportedCity                               │ VARCHAR                  │
# │ reportedZipCode                            │ VARCHAR                  │
# │ countyCode                                 │ VARCHAR                  │
# │ censusTract                                │ VARCHAR                  │
# │ censusBlockGroupFips                       │ VARCHAR                  │
# │ latitude                                   │ DECIMAL(9,1)             │
# │ longitude                                  │ DECIMAL(9,1)             │
# │ id                                         │ UUID                     │
# ├────────────────────────────────────────────┴──────────────────────────┤
# │ 73 rows                                                     2 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %%
# approximate column null percentage
con.sql("""
    SELECT
        column_name,
        null_percentage
    FROM (SUMMARIZE FROM claims)
    ORDER BY null_percentage DESC
""").show(max_rows=80)
# Out:
# ┌────────────────────────────────────────────┬─────────────────┐
# │                column_name                 │ null_percentage │
# │                  varchar                   │  decimal(9,2)   │
# ├────────────────────────────────────────────┼─────────────────┤
# │ asOfDate                                   │           99.38 │
# │ floodCharacteristicsIndicator              │           98.53 │
# │ crsClassificationCode                      │           95.09 │
# │ eventDesignationNumber                     │           93.23 │
# │ lowestAdjacentGrade                        │           81.09 │
# │ elevationCertificateIndicator              │           77.93 │
# │ nonPaymentReasonBuilding                   │           77.93 │
# │ lowestFloorElevation                       │           76.37 │
# │ baseFloodElevation                         │           75.68 │
# │ elevationDifference                        │           72.96 │
# │ floodZoneCurrent                           │           71.68 │
# │ nfipCommunityNumberCurrent                 │           71.63 │
# │ basementEnclosureCrawlspaceType            │           69.81 │
# │ nfipCommunityName                          │           69.69 │
# │ nonPaymentReasonContents                   │           68.56 │
# │ buildingDescriptionCode                    │           63.98 │
# │ contentsReplacementCost                    │           58.53 │
# │ contentsDamageAmount                       │           58.50 │
# │ contentsPropertyValue                      │           58.50 │
# │ obstructionType                            │           44.31 │
# │ ficoNumber                                 │           36.24 │
# │ locationOfContents                         │           33.84 │
# │ floodEvent                                 │           28.23 │
# │ iccCoverage                                │           27.73 │
# │ buildingPropertyValue                      │           22.16 │
# │ buildingReplacementCost                    │           22.16 │
# │ buildingDamageAmount                       │           22.08 │
# │ amountPaidOnBuildingClaim                  │           20.94 │
# │ amountPaidOnContentsClaim                  │           20.94 │
# │ amountPaidOnIncreasedCostOfComplianceClaim │           20.94 │
# │ contentsDeductibleCode                     │           20.20 │
# │ disasterAssistanceCoverageRequired         │           14.41 │
# │ floodWaterDuration                         │           10.22 │
# │ buildingDeductibleCode                     │            9.92 │
# │ waterDepth                                 │            8.72 │
# │ replacementCostBasis                       │            7.17 │
# │ ratedFloodZone                             │            5.13 │
# │ censusTract                                │            5.07 │
# │ censusBlockGroupFips                       │            5.07 │
# │ countyCode                                 │            2.30 │
# │ latitude                                   │            1.52 │
# │ longitude                                  │            1.52 │
# │ causeOfDamage                              │            1.39 │
# │ condominiumCoverageTypeCode                │            1.38 │
# │ rateMethod                                 │            1.23 │
# │ numberOfFloorsInTheInsuredBuilding         │            0.64 │
# │ numberOfUnits                              │            0.10 │
# │ originalConstructionDate                   │            0.07 │
# │ occupancyType                              │            0.02 │
# │ agricultureStructureIndicator              │            0.00 │
# │ policyCount                                │            0.00 │
# │ dateOfLoss                                 │            0.00 │
# │ elevatedBuildingIndicator                  │            0.00 │
# │ houseWorship                               │            0.00 │
# │ nonProfitIndicator                         │            0.00 │
# │ originalNBDate                             │            0.00 │
# │ postFIRMConstructionIndicator              │            0.00 │
# │ smallBusinessIndicatorBuilding             │            0.00 │
# │ totalBuildingInsuranceCoverage             │            0.00 │
# │ totalContentsInsuranceCoverage             │            0.00 │
# │ yearOfLoss                                 │            0.00 │
# │ primaryResidenceIndicator                  │            0.00 │
# │ netBuildingPaymentAmount                   │            0.00 │
# │ netContentsPaymentAmount                   │            0.00 │
# │ floodproofedIndicator                      │            0.00 │
# │ netIccPaymentAmount                        │            0.00 │
# │ nfipRatedCommunityNumber                   │            0.00 │
# │ stateOwnedIndicator                        │            0.00 │
# │ rentalPropertyIndicator                    │            0.00 │
# │ state                                      │            0.00 │
# │ reportedCity                               │            0.00 │
# │ reportedZipCode                            │            0.00 │
# │ id                                         │            0.00 │
# ├────────────────────────────────────────────┴─────────────────┤
# │ 73 rows                                            2 columns │
# └──────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Preview Data

# %%
# preview data as pandas dataframe for readability
sql = """
    SELECT *
    FROM claims
    LIMIT 5
"""

# examine each column in sections because of large number of columns
con.sql(sql).df().iloc[:, :15]
# Out:
#    agricultureStructureIndicator asOfDate  basementEnclosureCrawlspaceType  \
# 0                          False      NaT                              0.0
# 1                          False      NaT                              0.0
# 2                          False      NaT                              NaN
# 3                          False      NaT                              NaN
# 4                          False      NaT                              0.0
#
#    policyCount  crsClassificationCode dateOfLoss  elevatedBuildingIndicator  \
# 0            1                    NaN 2012-10-29                       True
# 1            1                    NaN 2017-08-26                      False
# 2            1                    8.0 2012-10-29                      False
# 3            1                    NaN 2017-08-26                       True
# 4            1                    5.0 2022-09-28                      False
#
#   elevationCertificateIndicator  elevationDifference  baseFloodElevation  \
# 0                          None                  1.0                 9.0
# 1                          None                  4.0                67.0
# 2                             3                  3.0                 7.0
# 3                          None                  NaN                 NaN
# 4                          None                 -6.0                10.0
#
#   ratedFloodZone  houseWorship  locationOfContents  lowestAdjacentGrade  \
# 0             AE         False                 3.0                  0.0
# 1             AE         False                 3.0                 69.5
# 2             AE         False                 NaN                  0.0
# 3              X         False                 3.0                  NaN
# 4             AE         False                 3.0                  3.9
#
#    lowestFloorElevation
# 0                   9.7
# 1                  70.5
# 2                   9.7
# 3                   NaN
# 4                   4.3

# %%
# slice through columns
con.sql(sql).df().iloc[:, 15:30]
# Out:
#    numberOfFloorsInTheInsuredBuilding  nonProfitIndicator  obstructionType  \
# 0                                   2               False             10.0
# 1                                   1               False              NaN
# 2                                   2               False              NaN
# 3                                   1               False             10.0
# 4                                   1               False              NaN
#
#    occupancyType originalConstructionDate originalNBDate  \
# 0             12               1970-11-26     2000-01-01
# 1             11               2001-01-01     2006-02-13
# 2              1               1987-07-01     1994-02-20
# 3              1               1978-01-01     2002-06-20
# 4             11               1978-01-01     2010-06-01
#
#    amountPaidOnBuildingClaim  amountPaidOnContentsClaim  \
# 0                        NaN                        NaN
# 1                   50292.22                   11607.90
# 2                   16320.60                       0.00
# 3                   27213.28                    8526.54
# 4                  250000.00                   27000.00
#
#    amountPaidOnIncreasedCostOfComplianceClaim  postFIRMConstructionIndicator  \
# 0                                         NaN                          False
# 1                                         0.0                           True
# 2                                         0.0                           True
# 3                                         0.0                          False
# 4                                         0.0                          False
#
#      rateMethod  smallBusinessIndicatorBuilding  \
# 0  RatingEngine                           False
# 1  RatingEngine                           False
# 2             1                           False
# 3             7                           False
# 4  RatingEngine                           False
#
#    totalBuildingInsuranceCoverage  totalContentsInsuranceCoverage  yearOfLoss
# 0                               0                           86000        2012
# 1                          250000                           83000        2017
# 2                          133100                               0        2012
# 3                          250000                          100000        2017
# 4                          250000                           29000        2022

# %%
# slice through columns
con.sql(sql).df().iloc[:, 30:45]
# Out:
#    primaryResidenceIndicator  buildingDamageAmount buildingDeductibleCode  \
# 0                      False                   NaN                   None
# 1                       True               51542.0                      F
# 2                       True               14534.0                      F
# 3                      False               28004.0                      F
# 4                       True              260584.0                      2
#
#    netBuildingPaymentAmount  buildingPropertyValue causeOfDamage  \
# 0                      0.00                    NaN          None
# 1                  50292.22               144996.0             0
# 2                  16320.60               135978.0             1
# 3                  27213.28               113293.0             4
# 4                 250000.00               279207.0             4
#
#   condominiumCoverageTypeCode  contentsDamageAmount contentsDeductibleCode  \
# 0                           N                   NaN                      1
# 1                           N               12858.0                      1
# 2                           N                   NaN                      0
# 3                           N                9776.0                      F
# 4                           N               38518.0                      2
#
#    netContentsPaymentAmount  contentsPropertyValue  \
# 0                      0.00                    NaN
# 1                  11607.90                48910.0
# 2                      0.00                    NaN
# 3                   8526.54                90000.0
# 4                  27000.00               279207.0
#
#    disasterAssistanceCoverageRequired eventDesignationNumber  ficoNumber  \
# 0                                 NaN                   None       305.0
# 1                                 NaN                   None       682.0
# 2                                 0.0                   None       305.0
# 3                                 0.0                   None       682.0
# 4                                 NaN                 FL0222         NaN
#
#    floodCharacteristicsIndicator
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
# slice through columns
con.sql(sql).df().iloc[:, 45:60]
# Out:
#    floodWaterDuration  floodproofedIndicator        floodEvent  iccCoverage  \
# 0                 0.0                  False   Hurricane Sandy          NaN
# 1                 0.0                  False  Hurricane Harvey      30000.0
# 2                 0.0                  False   Hurricane Sandy      30000.0
# 3                 0.0                  False  Hurricane Harvey      30000.0
# 4                 NaN                  False     Hurricane Ian      30000.0
#
#    netIccPaymentAmount nfipRatedCommunityNumber nfipCommunityNumberCurrent  \
# 0                  0.0                   345310                     345310
# 1                  0.0                   480287                     480287
# 2                  0.0                   345293                     345293
# 3                  0.0                   480296                     480296
# 4                  0.0                   120673                     120673
#
#            nfipCommunityName nonPaymentReasonContents  \
# 0        OCEAN CITY, CITY OF                       99
# 1             HARRIS COUNTY*                     None
# 2    TOMS RIVER, TOWNSHIP OF                     None
# 3           HOUSTON, CITY OF                     None
# 4  FORT MYERS BEACH, TOWN OF                     None
#
#   nonPaymentReasonBuilding  numberOfUnits  buildingReplacementCost  \
# 0                     None              2                      NaN
# 1                     None              1                 196855.0
# 2                     None              1                 159241.0
# 3                     None              1                 122976.0
# 4                     None              1                 307589.0
#
#    contentsReplacementCost replacementCostBasis  stateOwnedIndicator
# 0                      NaN                    A                False
# 1                      0.0                    A                False
# 2                      NaN                    R                False
# 3                      0.0                    R                False
# 4                      0.0                    A                False

# %%
# slice through columns
con.sql(sql).df().iloc[:, 60:]
# Out:
#    waterDepth floodZoneCurrent  buildingDescriptionCode  \
# 0           0               AE                      1.0
# 1           1               AE                      1.0
# 2          24               AE                      NaN
# 3           1                X                      1.0
# 4           8               AE                      1.0
#
#    rentalPropertyIndicator state           reportedCity reportedZipCode  \
# 0                    False    NJ  Currently Unavailable           08226
# 1                    False    TX  Currently Unavailable           77039
# 2                    False    NJ  Currently Unavailable           08753
# 3                    False    TX  Currently Unavailable           77060
# 4                    False    FL  Currently Unavailable           33931
#
#   countyCode  censusTract censusBlockGroupFips  latitude  longitude  \
# 0      34009  34009020206         340090202062      39.2      -74.6
# 1      48201  48201222900         482012229003      29.9      -95.3
# 2      34029  34029723400         340297234002      40.0      -74.1
# 3      48201  48201222502         482012225022      29.9      -95.4
# 4      12071  12071060203         120710602032      26.4      -81.9
#
#                                      id
# 0  a4edd1e3-a2cc-4ea7-b379-a8c61361d60b
# 1  5fa56e50-7923-44f3-832b-e527f639f28f
# 2  ee43a296-bc2b-4b49-b5b1-cc2b28eb4dbb
# 3  2d96f6b6-d33b-4eda-8988-6ecbf481c5db
# 4  37577287-ba9f-4cea-a1ed-ddc88be18348

# %%
# count duplicate IDs
con.sql("""
    SELECT
        id,
        COUNT(id) AS count
    FROM claims
    GROUP BY id
    HAVING count > 1
""").show()
# Out:
# ┌──────┬───────┐
# │  id  │ count │
# │ uuid │ int64 │
# ├──────┴───────┤
# │    0 rows    │
# └──────────────┘

# %%
# earliest and latest record effective date
con.sql("""
    SELECT
        min(asOfDate) AS earliestAsOfDate,
        max(asOfDate) AS latestAsOfDate
    FROM claims
""").show()
# Out:
# ┌────────────────────────────┬───────────────────────────────┐
# │      earliestAsOfDate      │        latestAsOfDate         │
# │  timestamp with time zone  │   timestamp with time zone    │
# ├────────────────────────────┼───────────────────────────────┤
# │ 2019-09-19 09:45:58.926-04 │ 2025-05-09 10:37:51.032136-04 │
# └────────────────────────────┴───────────────────────────────┘

# %%
# top 5 most recent effective date claim records
con.sql("""
    SELECT
        asOfDate,
        dateOfLoss,
        floodEvent,
        state,
        ROUND(
            amountPaidOnBuildingClaim
            + amountPaidOnContentsClaim
            + amountPaidOnIncreasedCostOfComplianceClaim)::BIGINT AS paidTotalClaim
    FROM claims
    ORDER BY asOfDate DESC
    LIMIT 5
""").show()
# Out:
# ┌───────────────────────────────┬────────────┬──────────────────┬─────────┬────────────────┐
# │           asOfDate            │ dateOfLoss │    floodEvent    │  state  │ paidTotalClaim │
# │   timestamp with time zone    │    date    │     varchar      │ varchar │     int64      │
# ├───────────────────────────────┼────────────┼──────────────────┼─────────┼────────────────┤
# │ 2025-05-09 10:37:51.032136-04 │ 2024-10-09 │ Hurricane Milton │ FL      │          10000 │
# │ 2025-05-09 10:21:49.039634-04 │ 2009-11-14 │ NULL             │ NY      │          10742 │
# │ 2025-05-08 16:19:32.301581-04 │ 2017-09-11 │ Hurricane Irma   │ FL      │           5000 │
# │ 2025-05-08 14:13:59.390838-04 │ 2012-10-29 │ Hurricane Sandy  │ CT      │          29514 │
# │ 2025-05-08 13:47:50.294098-04 │ 2010-09-08 │ NULL             │ TX      │          71758 │
# └───────────────────────────────┴────────────┴──────────────────┴─────────┴────────────────┘

# %%
# earliest and latest date of loss in dataset
con.sql("""
    SELECT
        min(dateOfLoss) AS earliestDateOfLoss,
        max(dateOfLoss) AS latestDateOfLoss
    FROM claims
""").show()
# Out:
# ┌────────────────────┬──────────────────┐
# │ earliestDateOfLoss │ latestDateOfLoss │
# │        date        │       date       │
# ├────────────────────┼──────────────────┤
# │ 1978-01-01         │ 2025-05-08       │
# └────────────────────┴──────────────────┘

# %%
# top 5 latest claim records by date of loss 
con.sql("""
    SELECT
        dateOfLoss,
        asOfDate,
        floodEvent,
        state,
        ROUND(
            amountPaidOnBuildingClaim
            + amountPaidOnContentsClaim
            + amountPaidOnIncreasedCostOfComplianceClaim)::BIGINT AS paidTotalClaim
    FROM claims
    ORDER BY dateOfLoss DESC, asOfDate DESC
    LIMIT 5
""").show()
# Out:
# ┌────────────┬──────────────────────────┬────────────┬─────────┬────────────────┐
# │ dateOfLoss │         asOfDate         │ floodEvent │  state  │ paidTotalClaim │
# │    date    │ timestamp with time zone │  varchar   │ varchar │     int64      │
# ├────────────┼──────────────────────────┼────────────┼─────────┼────────────────┤
# │ 2025-05-08 │ NULL                     │ NULL       │ TX      │           NULL │
# │ 2025-05-07 │ NULL                     │ NULL       │ LA      │           NULL │
# │ 2025-05-07 │ NULL                     │ NULL       │ LA      │           NULL │
# │ 2025-05-07 │ NULL                     │ NULL       │ LA      │           NULL │
# │ 2025-05-07 │ NULL                     │ NULL       │ LA      │           NULL │
# └────────────┴──────────────────────────┴────────────┴─────────┴────────────────┘

# %%
# top 5 latest claim records by date of loss where total paid claim > 0
con.sql("""
    SELECT
        dateOfLoss,
        asOfDate,
        floodEvent,
        state,
        ROUND(
            amountPaidOnBuildingClaim
            + amountPaidOnContentsClaim
            + amountPaidOnIncreasedCostOfComplianceClaim)::BIGINT AS paidTotalClaim
    FROM claims
    WHERE paidTotalClaim > 0
    ORDER BY dateOfLoss DESC, asOfDate DESC
    LIMIT 5
""").show()
# Out:
# ┌────────────┬──────────────────────────┬─────────────────────────────┬─────────┬────────────────┐
# │ dateOfLoss │         asOfDate         │         floodEvent          │  state  │ paidTotalClaim │
# │    date    │ timestamp with time zone │           varchar           │ varchar │     int64      │
# ├────────────┼──────────────────────────┼─────────────────────────────┼─────────┼────────────────┤
# │ 2025-04-28 │ NULL                     │ NULL                        │ KS      │           5000 │
# │ 2025-04-26 │ NULL                     │ NULL                        │ OK      │          89711 │
# │ 2025-04-26 │ NULL                     │ NULL                        │ OK      │           5469 │
# │ 2025-04-25 │ NULL                     │ NULL                        │ LA      │          12000 │
# │ 2025-04-25 │ NULL                     │ Central U.S. April Flooding │ OH      │          10000 │
# └────────────┴──────────────────────────┴─────────────────────────────┴─────────┴────────────────┘

# %%
# total insured units in dataset
con.sql("""
    SELECT SUM(policyCount) AS totalPolicyCount
    FROM claims
""").show()
# Out:
# ┌──────────────────┐
# │ totalPolicyCount │
# │      int128      │
# ├──────────────────┤
# │          3556310 │
# └──────────────────┘

# %% [markdown]
# Policy Count:
# >Insured units in an active status. A policy contract ceases to be in an active status as of the cancellation date or the expiration date. Residential Condominium Building Association Policy (RCBAP) contracts are stored as a single policy contract but insure multiple units and therefore represent multiple policies.
#
# Source: https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2

# %% [markdown]
# ## Summary Statistics

# %%
# calculate summary statistics of each column, pandas df for readability
summarize_df = con.sql("""
    SELECT *
    FROM (SUMMARIZE claims)
""").df()

summarize_df.head()
# Out:
#                        column_name               column_type  \
# 0    agricultureStructureIndicator                   BOOLEAN
# 1                         asOfDate  TIMESTAMP WITH TIME ZONE
# 2  basementEnclosureCrawlspaceType                  SMALLINT
# 3                      policyCount                  SMALLINT
# 4            crsClassificationCode                  SMALLINT
#
#                           min                            max  approx_unique  \
# 0                       false                           true              2
# 1  2019-09-19 09:45:58.926-04  2025-05-09 10:37:51.032136-04           2020
# 2                           0                              4              4
# 3                           1                           1090            399
# 4                           2                             10              9
#
#                   avg                 std   q25   q50   q75    count  \
# 0                None                None  None  None  None  2712269
# 1                None                None  None  None  None  2712269
# 2  1.1770725064274417  1.0645721195210949     0     1     2  2712269
# 3  1.3111936905963235     6.7764159242846     1     1     1  2712269
# 4   7.097005736252515  1.2044385650414646     6     7     8  2712269
#
#    null_percentage
# 0             0.00
# 1            99.38
# 2            69.81
# 3             0.00
# 4            95.09

# %%
# slice through columns for readability
summarize_df.iloc[:15, :]
# Out:
#                         column_name               column_type  \
# 0     agricultureStructureIndicator                   BOOLEAN
# 1                          asOfDate  TIMESTAMP WITH TIME ZONE
# 2   basementEnclosureCrawlspaceType                  SMALLINT
# 3                       policyCount                  SMALLINT
# 4             crsClassificationCode                  SMALLINT
# 5                        dateOfLoss                      DATE
# 6         elevatedBuildingIndicator                   BOOLEAN
# 7     elevationCertificateIndicator                   VARCHAR
# 8               elevationDifference              DECIMAL(6,1)
# 9                baseFloodElevation              DECIMAL(6,1)
# 10                   ratedFloodZone                   VARCHAR
# 11                     houseWorship                   BOOLEAN
# 12               locationOfContents                  SMALLINT
# 13              lowestAdjacentGrade              DECIMAL(6,1)
# 14             lowestFloorElevation              DECIMAL(6,1)
#
#                            min                            max  approx_unique  \
# 0                        false                           true              2
# 1   2019-09-19 09:45:58.926-04  2025-05-09 10:37:51.032136-04           2020
# 2                            0                              4              4
# 3                            1                           1090            399
# 4                            2                             10              9
# 5                   1978-01-01                     2025-05-08          17092
# 6                        false                           true              2
# 7                            1                              E              9
# 8                      -9989.0                          998.0            374
# 9                      -9999.0                         9998.0          10670
# 10                           A                              X             73
# 11                       false                           true              2
# 12                           1                              7              7
# 13                    -99999.9                         9998.9          12901
# 14                     -9999.0                         9998.9          13545
#
#                    avg                 std   q25   q50   q75    count  \
# 0                 None                None  None  None  None  2712269
# 1                 None                None  None  None  None  2712269
# 2   1.1770725064274417  1.0645721195210949     0     1     2  2712269
# 3   1.3111936905963235     6.7764159242846     1     1     1  2712269
# 4    7.097005736252515  1.2044385650414646     6     7     8  2712269
# 5                 None                None  None  None  None  2712269
# 6                 None                None  None  None  None  2712269
# 7                 None                None  None  None  None  2712269
# 8   1.2412984434821497   28.89929695021127     0     1     3  2712269
# 9   127.91883349679618   771.9052642868454     7     9    14  2712269
# 10                None                None  None  None  None  2712269
# 11                None                None  None  None  None  2712269
# 12  3.2159722655657896  0.9861239199705663     3     3     4  2712269
# 13  51.968295779427194  1432.8378247606709     3     6    11  2712269
# 14   98.36419546819546   563.3530371105021     7    10    17  2712269
#
#     null_percentage
# 0              0.00
# 1             99.38
# 2             69.81
# 3              0.00
# 4             95.09
# 5              0.00
# 6              0.00
# 7             77.93
# 8             72.96
# 9             75.68
# 10             5.13
# 11             0.00
# 12            33.84
# 13            81.09
# 14            76.37

# %%
# slice through columns for readability
summarize_df.iloc[15:30, :]
# Out:
#                                    column_name    column_type         min  \
# 15          numberOfFloorsInTheInsuredBuilding       SMALLINT           1
# 16                          nonProfitIndicator        BOOLEAN       false
# 17                             obstructionType       SMALLINT          10
# 18                               occupancyType       SMALLINT           1
# 19                    originalConstructionDate           DATE  1069-01-01
# 20                              originalNBDate           DATE  0998-09-21
# 21                   amountPaidOnBuildingClaim  DECIMAL(12,2)  -201667.50
# 22                   amountPaidOnContentsClaim  DECIMAL(12,2)   -80000.00
# 23  amountPaidOnIncreasedCostOfComplianceClaim  DECIMAL(12,2)    -6450.00
# 24               postFIRMConstructionIndicator        BOOLEAN       false
# 25                                  rateMethod        VARCHAR           1
# 26              smallBusinessIndicatorBuilding        BOOLEAN       false
# 27              totalBuildingInsuranceCoverage         BIGINT           0
# 28              totalContentsInsuranceCoverage         BIGINT           0
# 29                                  yearOfLoss       SMALLINT        1978
#
#             max  approx_unique                 avg                 std    q25  \
# 15            6              6  1.6938736284429694  0.8766122533916554      1
# 16         true              2                None                None   None
# 17           98             20  16.647995328689827  16.220438899177925     10
# 18           19             14   3.409205010736819   4.302312472419813      1
# 19   2025-01-24          32065                None                None   None
# 20   2025-06-10          18008                None                None   None
# 21  10741476.93        1340761   33420.77803829708   70287.17975307132   2372
# 22    757048.95         491712   7241.491405149647   22309.39540062048      0
# 23     60000.00           8778  443.98579255351643  3430.7187165367727      0
# 24         true              2                None                None   None
# 25            W             21                None                None   None
# 26         true              2                None                None   None
# 27    272500000          11244  194399.31717586593   1337199.178962068  45465
# 28      3050000           2945   34928.62616500591   53950.78621191847      0
# 29         2025             48  2002.9699624189193  12.954617696294777   1994
#
#        q50     q75    count  null_percentage
# 15       1       2  2712269             0.64
# 16    None    None  2712269             0.00
# 17      10      10  2712269            44.31
# 18       1       4  2712269             0.02
# 19    None    None  2712269             0.07
# 20    None    None  2712269             0.00
# 21   10013   39430  2712269            20.94
# 22       0    4930  2712269            20.94
# 23       0       0  2712269            20.94
# 24    None    None  2712269             0.00
# 25    None    None  2712269             1.23
# 26    None    None  2712269             0.00
# 27  123157  250000  2712269             0.00
# 28   14227   53347  2712269             0.00
# 29    2005    2012  2712269             0.00

# %%
# slice through columns for readability
summarize_df.iloc[30:45, :]
# Out:
#                            column_name    column_type         min  \
# 30           primaryResidenceIndicator        BOOLEAN       false
# 31                buildingDamageAmount         BIGINT           0
# 32              buildingDeductibleCode        VARCHAR           0
# 33            netBuildingPaymentAmount  DECIMAL(12,2)  -201667.50
# 34               buildingPropertyValue         BIGINT           0
# 35                       causeOfDamage        VARCHAR           0
# 36         condominiumCoverageTypeCode        VARCHAR           A
# 37                contentsDamageAmount         BIGINT           0
# 38              contentsDeductibleCode        VARCHAR           0
# 39            netContentsPaymentAmount  DECIMAL(12,2)   -80000.00
# 40               contentsPropertyValue         BIGINT          -1
# 41  disasterAssistanceCoverageRequired       SMALLINT           0
# 42              eventDesignationNumber        VARCHAR      AL0221
# 43                          ficoNumber       SMALLINT           1
# 44       floodCharacteristicsIndicator       SMALLINT           1
#
#             max  approx_unique                  avg                 std  \
# 30         true              2                 None                None
# 31    927700000         212080    38208.02455475229   797984.7176002406
# 32            H             15                 None                None
# 33  10741476.93        1340258   26392.024846635788   63904.97125793367
# 34   2143596000         441823   1178552.9682516525   33428601.47466117
# 35            Z             17                 None                None
# 36            U              5                 None                None
# 37     19230507         104391    18433.39366964457   84558.06826232812
# 38            H             15                 None                None
# 39    757048.95         491683   5703.9727689841975  20032.401811819273
# 40    281895323          71334   35725.314603277824  499219.84041084634
# 41            5              6  0.05562062478811816  0.4736151152099379
# 42       WV0421             68                 None                None
# 43          998            733    500.7086411271528  237.25347160569245
# 44            5              5   1.8946377938925552  0.5954632949188176
#
#       q25     q50     q75    count  null_percentage
# 30   None    None    None  2712269             0.00
# 31   3541   11716   43005  2712269            22.08
# 32   None    None    None  2712269             9.92
# 33      4    4967   26814  2712269             0.00
# 34  61439  112388  195772  2712269            22.16
# 35   None    None    None  2712269             1.39
# 36   None    None    None  2712269             1.38
# 37   1569    5746   18956  2712269            58.50
# 38   None    None    None  2712269            20.20
# 39      0       0    2342  2712269             0.00
# 40      0       0   20844  2712269            58.50
# 41      0       0       0  2712269            14.41
# 42   None    None    None  2712269            93.23
# 43    305     593     655  2712269            36.24
# 44      2       2       2  2712269            98.53

# %%
# slice through columns for readability
summarize_df.iloc[45:60, :]
# Out:
#                    column_name   column_type                            min  \
# 45          floodWaterDuration      SMALLINT                              0
# 46       floodproofedIndicator       BOOLEAN                          false
# 47                  floodEvent       VARCHAR  2021 Mid-Spring Severe Storms
# 48                 iccCoverage       INTEGER                              0
# 49         netIccPaymentAmount  DECIMAL(8,2)                       -6450.00
# 50    nfipRatedCommunityNumber       VARCHAR                         000000
# 51  nfipCommunityNumberCurrent       VARCHAR                           0000
# 52           nfipCommunityName       VARCHAR             ABBEVILLE COUNTY *
# 53    nonPaymentReasonContents       VARCHAR                             01
# 54    nonPaymentReasonBuilding       VARCHAR                             01
# 55               numberOfUnits       INTEGER                              0
# 56     buildingReplacementCost        BIGINT                              0
# 57     contentsReplacementCost        BIGINT                              0
# 58        replacementCostBasis       VARCHAR                              A
# 59         stateOwnedIndicator       BOOLEAN                          false
#
#                       max  approx_unique                 avg  \
# 45                    999            261  0.8052723609654414
# 46                   true              2                None
# 47   Yellowstone Flooding            181                None
# 48                  30000              4  28265.786678448367
# 49               60000.00           8735    349.706785562199
# 50                 999999          16336                None
# 51                 815000          12126                None
# 52  ZUMBRO FALLS, CITY OF           9918                None
# 53                     99             23                None
# 54                     99             23                None
# 55                  99999            453  1.4238491524810681
# 56             2147400000         470294   1361595.427023883
# 57               20000000           9395  2946.1105946699477
# 58                      R              2                None
# 59                   true              2                None
#
#                    std    q25     q50     q75    count  null_percentage
# 45  14.711450527028969      0       0       0  2712269            10.22
# 46                None   None    None    None  2712269             0.00
# 47                None   None    None    None  2712269            28.23
# 48   4401.656086048918  30000   30000   30000  2712269            27.73
# 49  3049.9895153999505      0       0       0  2712269             0.00
# 50                None   None    None    None  2712269             0.00
# 51                None   None    None    None  2712269            71.63
# 52                None   None    None    None  2712269            69.69
# 53                None   None    None    None  2712269            68.56
# 54                None   None    None    None  2712269            77.93
# 55   64.97661157163928      1       1       1  2712269             0.10
# 56   36825292.65722829      0  125040  232668  2712269            22.16
# 57   46050.09229366389      0       0       0  2712269            58.53
# 58                None   None    None    None  2712269             7.17
# 59                None   None    None    None  2712269             0.00

# %%
# slice through columns for readability
summarize_df.iloc[60:, :]
# Out:
#                 column_name   column_type  \
# 60               waterDepth      SMALLINT
# 61         floodZoneCurrent       VARCHAR
# 62  buildingDescriptionCode      SMALLINT
# 63  rentalPropertyIndicator       BOOLEAN
# 64                    state       VARCHAR
# 65             reportedCity       VARCHAR
# 66          reportedZipCode       VARCHAR
# 67               countyCode       VARCHAR
# 68              censusTract       VARCHAR
# 69     censusBlockGroupFips       VARCHAR
# 70                 latitude  DECIMAL(9,1)
# 71                longitude  DECIMAL(9,1)
# 72                       id          UUID
#
#                                      min  \
# 60                                  -999
# 61                                     A
# 62                                     1
# 63                                 false
# 64                                    AK
# 65                 Currently Unavailable
# 66
# 67                                 01001
# 68                           01001020100
# 69                          010010201001
# 70                                 -36.0
# 71                                -170.7
# 72  00000713-a024-49a3-8ac1-ad0a014110ea
#
#                                      max  approx_unique                 avg  \
# 60                                   999            477  4.3734550934507155
# 61                                     X             62                None
# 62                                    21             18  1.3388721969995547
# 63                                  true              2                None
# 64                                    WY             57                None
# 65                 Currently Unavailable              1                None
# 66                                 99999          26382                None
# 67                                 78030           2950                None
# 68                           78030961200          61953                None
# 69                          780309612002         122677                None
# 70                                  69.9            333   33.68537970095966
# 71                                 174.0            713  -85.98901878886267
# 72  fffffe29-0b7d-4c0d-aad0-f1f150a1d625        2780604                None
#
#                    std   q25   q50   q75    count  null_percentage
# 60    16.6137961933647     0     1     2  2712269             8.72
# 61                None  None  None  None  2712269            71.68
# 62  1.5010850565190803     1     1     1  2712269            63.98
# 63                None  None  None  None  2712269             0.00
# 64                None  None  None  None  2712269             0.00
# 65                None  None  None  None  2712269             0.00
# 66                None  None  None  None  2712269             0.00
# 67                None  None  None  None  2712269             2.30
# 68                None  None  None  None  2712269             5.07
# 69                None  None  None  None  2712269             5.07
# 70   5.829876497704541    30    31    40  2712269             1.52
# 71  10.884469561858305   -91   -86   -78  2712269             1.52
# 72                None  None  None  None  2712269             0.00

# %% [markdown]
# ## Highlighted Features: Amount Paid on Claims Summary Statistics
# We will analyze these attributes extensively throughout this notebook.
#
# **amountPaidOnBuildingClaim**: Dollar amount paid on the building claim. In some instances, a negative amount may appear which occurs when a check issued to a policy holder is not cashed and has to be re-issued.
#
# **amountPaidOnContentsClaim**: Dollar amount paid on the contents claim. In some instances, a negative amount may appear, which occurs when a check issued to a policy holder is not cashed and has to be re-issued.
#
# **amountPaidOnIncreasedCostOfComplianceClaim**: ICC coverage is one of several flood insurance resources for policyholders who need additional help rebuilding after a flood. It provides up to $30,000 to help cover the cost of mitigation measures that will reduce the flood risk.
#
# Source: https://www.fema.gov/openfema-data-page/fima-nfip-redacted-claims-v2
#
# Note: All dollar amounts are reported in nominal terms and have not been adjusted for inflation.

# %%
# examine summary statistics on paid total claims
con.sql("""
    SELECT
        column_name, column_type, count, null_percentage,
        min, max, approx_unique,
        ROUND(avg::DOUBLE, 2) AS avg,
        ROUND(std::DOUBLE, 2) AS std,
        ROUND(q25::DOUBLE, 2) AS q25,
        ROUND(q50::DOUBLE, 2) AS q50,
        ROUND(q75::DOUBLE, 2) AS q75
    FROM (SUMMARIZE claims)
    WHERE column_name IN (
        'amountPaidOnBuildingClaim',
        'amountPaidOnContentsClaim',
        'amountPaidOnIncreasedCostOfComplianceClaim'
    )
""").df()
# Out:
#                                   column_name    column_type    count  \
# 0                   amountPaidOnBuildingClaim  DECIMAL(12,2)  2712269
# 1                   amountPaidOnContentsClaim  DECIMAL(12,2)  2712269
# 2  amountPaidOnIncreasedCostOfComplianceClaim  DECIMAL(12,2)  2712269
#
#    null_percentage         min          max  approx_unique       avg  \
# 0            20.94  -201667.50  10741476.93        1340761  33420.78
# 1            20.94   -80000.00    757048.95         491712   7241.49
# 2            20.94    -6450.00     60000.00           8778    443.99
#
#         std     q25      q50      q75
# 0  70287.18  2375.0  10019.0  39481.0
# 1  22309.40     0.0      0.0   4920.0
# 2   3430.72     0.0      0.0      0.0

# %%
# top 10 paid total claim records
con.sql("""
    SELECT
        dateOfLoss,
        floodEvent,
        state,
        policyCount,
        ROUND(
            amountPaidOnBuildingClaim
            + amountPaidOnContentsClaim
            + amountPaidOnIncreasedCostOfComplianceClaim, 0)::INT AS paidTotalClaim,
        ROUND(amountPaidOnBuildingClaim, 0)::INT AS amountPaidOnBuildingClaim,
        ROUND(amountPaidOnContentsClaim, 0)::INT AS amountPaidOnContentsClaim,
        ROUND(amountPaidOnIncreasedCostOfComplianceClaim, 0)::INT AS amountPaidICC
    FROM claims
    ORDER BY paidTotalClaim DESC
    LIMIT 10
""").df()
# Out:
#   dateOfLoss              floodEvent state  policyCount  paidTotalClaim  \
# 0 2022-09-28           Hurricane Ian    FL          198        10841477
# 1 2005-08-29       Hurricane Katrina    MS           48        10000000
# 2 2012-10-29         Hurricane Sandy    NY          184         9467720
# 3 2004-09-15          Hurricane Ivan    FL           64         9169507
# 4 2001-06-09  Tropical Storm Allison    TX          233         9023558
# 5 2022-09-28           Hurricane Ian    FL           36         9000000
# 6 2022-09-28           Hurricane Ian    FL           72         8758773
# 7 2022-09-28           Hurricane Ian    FL           54         8734196
# 8 2005-08-29       Hurricane Katrina    MS           71         8386100
# 9 2022-09-28           Hurricane Ian    FL           51         7778937
#
#    amountPaidOnBuildingClaim  amountPaidOnContentsClaim  amountPaidICC
# 0                   10741477                     100000              0
# 1                   10000000                          0              0
# 2                    9467720                          0              0
# 3                    9100033                      39474          30000
# 4                    8973270                      50288              0
# 5                    9000000                          0              0
# 6                    8758773                          0              0
# 7                    8734196                          0              0
# 8                    8349000                      37100              0
# 9                    7778937                          0              0

# %%
# top 10 paid total claim records for only one policy
con.sql("""
    SELECT
        dateOfLoss,
        floodEvent,
        state,
        policyCount,
        ROUND(
            amountPaidOnBuildingClaim
            + amountPaidOnContentsClaim
            + amountPaidOnIncreasedCostOfComplianceClaim, 0)::INT AS paidTotalClaim,
        ROUND(amountPaidOnBuildingClaim, 0)::INT AS amountPaidOnBuildingClaim,
        ROUND(amountPaidOnContentsClaim, 0)::INT AS amountPaidOnContentsClaim,
        ROUND(amountPaidOnIncreasedCostOfComplianceClaim, 0)::INT AS amountPaidICC
    FROM claims
    WHERE policyCount == 1
    ORDER BY paidTotalClaim DESC
    LIMIT 10
""").df()
# Out:
#   dateOfLoss              floodEvent state  policyCount  paidTotalClaim  \
# 0 2008-06-13                    None    IA            1         1250000
# 1 2023-04-13  April Florida Flooding    FL            1         1065210
# 2 2016-05-24                    None    AR            1         1054205
# 3 2012-10-29         Hurricane Sandy    NJ            1         1050000
# 4 2012-10-29         Hurricane Sandy    NJ            1         1039512
# 5 2011-09-07      Tropical Storm Lee    NY            1         1000000
# 6 2001-06-05  Tropical Storm Allison    TX            1         1000000
# 7 2017-08-27        Hurricane Harvey    TX            1         1000000
# 8 2003-09-15                    None    DE            1         1000000
# 9 2011-09-07      Tropical Storm Lee    PA            1         1000000
#
#    amountPaidOnBuildingClaim  amountPaidOnContentsClaim  amountPaidICC
# 0                     500000                     750000              0
# 1                    1000000                      65210              0
# 2                     500000                     554205              0
# 3                     500000                     550000              0
# 4                     500000                     539512              0
# 5                     500000                     500000              0
# 6                     500000                     500000              0
# 7                     500000                     500000              0
# 8                     500000                     500000              0
# 9                     500000                     500000              0

# %% [markdown]
# ## Additional Attributes: Building Damage, Values, and Replacement Costs Summary Statistics

# %%
# examine summary statistics on building damage amounts, property values and replacement costs columns
con.sql("""
    SELECT
        column_name, column_type, count, null_percentage,
        min, max, approx_unique,
        ROUND(avg::DOUBLE, 2) AS avg,
        ROUND(std::DOUBLE, 2) AS std,
        ROUND(q25::DOUBLE, 2) AS q25,
        ROUND(q50::DOUBLE, 2) AS q50,
        ROUND(q75::DOUBLE, 2) AS q75,
    FROM (SUMMARIZE claims)
    WHERE column_name IN (
        'buildingPropertyValue',
        'buildingReplacementCost',
        'buildingDamageAmount'
    )
""").df()
# Out:
#                column_name column_type    count  null_percentage min  \
# 0    buildingPropertyValue      BIGINT  2712269            22.16   0
# 1  buildingReplacementCost      BIGINT  2712269            22.16   0
# 2     buildingDamageAmount      BIGINT  2712269            22.08   0
#
#           max  approx_unique         avg          std      q25       q50  \
# 0  2143596000         441823  1178552.97  33428601.47  61457.0  112345.0
# 1  2147400000         470294  1361595.43  36825292.66      0.0  125033.0
# 2   927700000         212080    38208.02    797984.72   3537.0   11726.0
#
#         q75
# 0  195667.0
# 1  232914.0
# 2   42962.0

# %% [markdown]
# ## Additional Attributes: Elevation and Water Depth Summary Statistics

# %%
# examine summary statisitics on elevation and water depth columns
con.sql("""
    SELECT
        column_name, column_type, count, null_percentage,
        min, max, approx_unique,
        ROUND(avg::DOUBLE, 2) AS avg,
        ROUND(std::DOUBLE, 2) AS std,
        ROUND(q25::DOUBLE, 2) AS q25,
        ROUND(q50::DOUBLE, 2) AS q50,
        ROUND(q75::DOUBLE, 2) AS q75
    FROM (SUMMARIZE claims)
    WHERE column_name IN (
        'baseFloodElevation',
        'waterDepth',
        'lowestAdjacentGrade',
        'lowestFloorElevation',
        'elevationDifference',
    )
""").df()
# Out:
#             column_name   column_type    count  null_percentage       min  \
# 0   elevationDifference  DECIMAL(6,1)  2712269            72.96   -9989.0
# 1    baseFloodElevation  DECIMAL(6,1)  2712269            75.68   -9999.0
# 2   lowestAdjacentGrade  DECIMAL(6,1)  2712269            81.09  -99999.9
# 3  lowestFloorElevation  DECIMAL(6,1)  2712269            76.37   -9999.0
# 4            waterDepth      SMALLINT  2712269             8.72      -999
#
#       max  approx_unique     avg      std  q25   q50   q75
# 0   998.0            374    1.24    28.90  0.0   1.0   3.0
# 1  9998.0          10670  127.92   771.91  7.0   9.0  14.0
# 2  9998.9          12901   51.97  1432.84  3.0   6.0  11.0
# 3  9998.9          13545   98.36   563.35  7.0  10.0  17.0
# 4     999            477    4.37    16.61  0.0   1.0   2.0

# %% [markdown]
# # Analysis
# Note: All dollar amounts are reported in nominal terms and have not been adjusted for inflation.

# %% [markdown]
# ## Claims Statistics

# %%
con.sql("""
    SELECT
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim, 
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
""").df()
# Out:
#    countClaims  paidTotalClaim  paidBuildingClaim  paidContentsClaim  \
# 0      2712269     88145828459        71665544599        15528226921
#
#      paidICC
# 0  952056938

# %% [markdown]
# **Table xx: Top 20 States by Number of Claims**

# %%
con.sql("""
    SELECT
        state,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim, 
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    GROUP BY state
    ORDER BY countClaims DESC
    LIMIT 20
""").df()
# Out:
#    state  countClaims  paidTotalClaim  paidBuildingClaim  paidContentsClaim  \
# 0     LA       484666     20947513582        16527767559         4141923176
# 1     FL       447278     18384455856        15836650628         2507931591
# 2     TX       392749     17278352758        13302979646         3917178105
# 3     NJ       201265      6475796363         5352658075          872585670
# 4     NY       174868      5736650506         4962160483          720696292
# 5     NC       108782      2229981486         1888471315          304395942
# 6     PA        76689      1434820809         1126172001          293470206
# 7     MS        64182      3123903360         2387164446          675757041
# 8     CA        53267       744106757          638192339          104848121
# 9     IL        52538       590353164          493999341           81082965
# 10    MO        51158       975684657          724583276          232960420
# 11    VA        50405       765794119          632007942          111467209
# 12    SC        49506      1035539113          898006633          133682678
# 13    AL        44835      1193138174          967795331          212455483
# 14    MA        35317       440592807          380305729           59007488
# 15    CT        29413       553669600          478042792           66145207
# 16    OH        28052       362463091          289417031           69653209
# 17    WV        27731       374776608          279129749           93228610
# 18    KY        27713       449589723          366753204           79892934
# 19    PR        25377       160996176           75938192           85057985
#
#       paidICC
# 0   277822847
# 1    39873637
# 2    58195007
# 3   250552618
# 4    53793731
# 5    37114230
# 6    15178602
# 7    60981873
# 8     1066297
# 9    15270858
# 10   18140962
# 11   22318968
# 12    3849802
# 13   12887360
# 14    1279589
# 15    9481601
# 16    3392850
# 17    2418250
# 18    2943585
# 19          0

# %% [markdown]
# **Table xx: Top 20 States by Total Paid Claims**

# %%
con.sql("""
    SELECT
        state,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim, 
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    GROUP BY state
    ORDER BY paidTotalClaim DESC
    LIMIT 20
""").df()
# Out:
#    state  countClaims  paidTotalClaim  paidBuildingClaim  paidContentsClaim  \
# 0     LA       484666     20947513582        16527767559         4141923176
# 1     FL       447278     18384455856        15836650628         2507931591
# 2     TX       392749     17278352758        13302979646         3917178105
# 3     NJ       201265      6475796363         5352658075          872585670
# 4     NY       174868      5736650506         4962160483          720696292
# 5     MS        64182      3123903360         2387164446          675757041
# 6     NC       108782      2229981486         1888471315          304395942
# 7     PA        76689      1434820809         1126172001          293470206
# 8     AL        44835      1193138174          967795331          212455483
# 9     SC        49506      1035539113          898006633          133682678
# 10    MO        51158       975684657          724583276          232960420
# 11    VA        50405       765794119          632007942          111467209
# 12    CA        53267       744106757          638192339          104848121
# 13    IL        52538       590353164          493999341           81082965
# 14    CT        29413       553669600          478042792           66145207
# 15    GA        24272       510660704          428008259           79925963
# 16    TN        17526       467221107          384952900           79086551
# 17    KY        27713       449589723          366753204           79892934
# 18    MA        35317       440592807          380305729           59007488
# 19    WV        27731       374776608          279129749           93228610
#
#       paidICC
# 0   277822847
# 1    39873637
# 2    58195007
# 3   250552618
# 4    53793731
# 5    60981873
# 6    37114230
# 7    15178602
# 8    12887360
# 9     3849802
# 10   18140962
# 11   22318968
# 12    1066297
# 13   15270858
# 14    9481601
# 15    2726482
# 16    3181656
# 17    2943585
# 18    1279589
# 19    2418250

# %% [markdown]
# **Table xx: Top 20 Counties by Number of Claims**

# %%
con.sql("""
    SELECT
        state,
        countyCode,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    GROUP BY state, countyCode
    ORDER BY countClaims DESC
    LIMIT 20
""").df()
# Out:
#    state countyCode  countClaims  paidTotalClaim  paidBuildingClaim  \
# 0     TX      48201       170714      8757473076         6801326001
# 1     LA      22051       135459      3581575679         2667508197
# 2     LA      22071       127191      7299472607         5895174387
# 3     FL      12086        61937       848599959          666613901
# 4     TX      48167        60588      2469378449         1898457084
# 5     NJ      34029        52800      2608104753         2160918465
# 6     FL      12103        51624      3358698015         2895731336
# 7     NY      36059        51486      2280445421         1973196756
# 8     FL      12071        48362      3837968086         3441477426
# 9     LA      22103        38318      1778918351         1381100007
# 10    FL      12011        34932       452160915          385252565
# 11    NY      36103        33888      1112850654          976991239
# 12    NJ      34009        27988       414332880          348463286
# 13    FL      12087        27416       713596717          602701153
# 14    LA      22087        23918      2245139592         1680136546
# 15    TX      48245        22627      1187523777          877025773
# 16    LA      22033        22513      1311988667         1140522853
# 17    TX      48039        21404       630858675          480285474
# 18    NJ      34001        20853       492524763          427606135
# 19    NJ      34025        19956       935187028          798908877
#
#     paidContentsClaim    paidICC
# 0          1936097596   20049478
# 1           852374316   61693166
# 2          1293804705  110493515
# 3           181986058          0
# 4           549950596   20970769
# 5           275259388  171926899
# 6           462233188     733492
# 7           290493947   16754717
# 8           393582512    2908147
# 9           383543475   14274869
# 10           66894350      14000
# 11          121435700   14423716
# 12           56025376    9844218
# 13          105831976    5063588
# 14          553968821   11034225
# 15          308172230    2325774
# 16          169458967    2006847
# 17          147050173    3523027
# 18           45183212   19735417
# 19           96644444   39633706

# %% [markdown]
# **Table xx: Top 20 Counties by Total Paid Claims**

# %%
con.sql("""
    SELECT
        state,
        countyCode,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    GROUP BY state, countyCode
    ORDER BY paidTotalClaim DESC
    LIMIT 20
""").df()
# Out:
#    state countyCode  countClaims  paidTotalClaim  paidBuildingClaim  \
# 0     TX      48201       170714      8757473076         6801326001
# 1     LA      22071       127191      7299472607         5895174387
# 2     FL      12071        48362      3837968086         3441477426
# 3     LA      22051       135459      3581575679         2667508197
# 4     FL      12103        51624      3358698015         2895731336
# 5     NJ      34029        52800      2608104753         2160918465
# 6     TX      48167        60588      2469378449         1898457084
# 7     NY      36059        51486      2280445421         1973196756
# 8     LA      22087        23918      2245139592         1680136546
# 9     LA      22103        38318      1778918351         1381100007
# 10    LA      22033        22513      1311988667         1140522853
# 11    MS      28047        15792      1286619783          982209663
# 12    TX      48245        22627      1187523777          877025773
# 13    NY      36103        33888      1112850654          976991239
# 14    FL      12021        14725      1104196077          980575557
# 15    FL      12057        18465      1092576795          946351562
# 16    TX      48361        12850      1042862073          740543331
# 17    NJ      34025        19956       935187028          798908877
# 18    FL      12086        61937       848599959          666613901
# 19    LA      22063        14634       834962481          716200103
#
#     paidContentsClaim    paidICC
# 0          1936097596   20049478
# 1          1293804705  110493515
# 2           393582512    2908147
# 3           852374316   61693166
# 4           462233188     733492
# 5           275259388  171926899
# 6           549950596   20970769
# 7           290493947   16754717
# 8           553968821   11034225
# 9           383543475   14274869
# 10          169458967    2006847
# 11          283679372   20730748
# 12          308172230    2325774
# 13          121435700   14423716
# 14          122681286     939234
# 15          145960489     264745
# 16          301508841     809902
# 17           96644444   39633706
# 18          181986058          0
# 19          113418020    5344358

# %% [markdown]
# **Table xx: Top 20 Flood Events by Number of Claims**

# %%
con.sql("""
    SELECT
        floodEvent,
        yearOfLoss,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    WHERE floodEvent NOT NULL
    GROUP BY floodEvent, yearOfLoss
    ORDER BY countClaims DESC
    LIMIT 20
""").df()
# Out:
#                      floodEvent  yearOfLoss  countClaims  paidTotalClaim  \
# 0             Hurricane Katrina        2005       208348     16261697056
# 1               Hurricane Sandy        2012       144848      8957466107
# 2              Hurricane Harvey        2017        92398      9055711922
# 3                 Hurricane Ike        2008        58126      2702511916
# 4              Hurricane Helene        2024        57843      6027667592
# 5               Hurricane Irene        2011        52493      1347399996
# 6                 Hurricane Ian        2022        48754      4838681069
# 7                      Flooding        1995        47489       731729839
# 8        Tropical Storm Allison        2001        35561      1104979705
# 9                Hurricane Irma        2017        33339      1114753522
# 10  December Storm - Nor'easter        1992        30314       346119922
# 11     Mid-summer severe storms        2016        30018      2533534783
# 12                Hurricane Ida        2021        28317      1347194328
# 13                     Flooding        1980        27561       140880936
# 14              Hurricane Floyd        1999        27447       462286436
# 15                     Flooding        1998        26606       375921934
# 16                     Flooding        1996        25114       328800365
# 17             Hurricane Isabel        2003        23955       500076497
# 18                     Flooding        1983        23619       205146718
# 19                     Flooding        1984        22072       185473462
#
#     paidBuildingClaim  paidContentsClaim    paidICC
# 0         12659081935         3360020221  242594900
# 1          7707744797          951637071  298084239
# 2          6925370027         2115077279   15264616
# 3          2073801567          577791589   50918760
# 4          5294925051          731897793     844748
# 5          1139897981          183189121   24312894
# 6          4306968612          528552815    3159642
# 7           554632707          177097132          0
# 8           820333554          279280479    5365672
# 9           945900736          162153778    6699008
# 10          289085251           57034670          0
# 11         2175218939          347276988   11038856
# 12         1115954177          229931261    1308891
# 13           97465147           43415789          0
# 14          365576466           94481482    2228488
# 15          278346877           95267999    2307059
# 16          252919784           75880581          0
# 17          408652888           59803277   31620332
# 18          150709917           54436801          0
# 19          122042010           63431453          0

# %% [markdown]
# **Table xx: Top 20 Flood Events by Total Paid Claims**

# %%
con.sql("""
    SELECT
        floodEvent,
        yearOfLoss,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    WHERE floodEvent NOT NULL
    GROUP BY floodEvent, yearOfLoss
    ORDER BY paidTotalClaim DESC
    LIMIT 20
""").df()
# Out:
#                   floodEvent  yearOfLoss  countClaims  paidTotalClaim  \
# 0          Hurricane Katrina        2005       208348     16261697056
# 1           Hurricane Harvey        2017        92398      9055711922
# 2            Hurricane Sandy        2012       144848      8957466107
# 3           Hurricane Helene        2024        57843      6027667592
# 4              Hurricane Ian        2022        48754      4838681069
# 5              Hurricane Ike        2008        58126      2702511916
# 6   Mid-summer severe storms        2016        30018      2533534783
# 7            Hurricane Irene        2011        52493      1347399996
# 8              Hurricane Ida        2021        28317      1347194328
# 9             Hurricane Ivan        2004        20137      1325419294
# 10            Hurricane Irma        2017        33339      1114753522
# 11    Tropical Storm Allison        2001        35561      1104979705
# 12          Hurricane Milton        2024        21460      1043699385
# 13     Tropical Storm Imelda        2019        10940       752448943
# 14        Hurricane Florence        2018        16801       743470849
# 15                  Flooding        1995        47489       731729839
# 16         Hurricane Matthew        2016        21818       662074495
# 17           Hurricane Isaac        2012        16926       564085634
# 18          Hurricane Isabel        2003        23955       500076497
# 19       Early summer storms        2015         8354       487790879
#
#     paidBuildingClaim  paidContentsClaim    paidICC
# 0         12659081935         3360020221  242594900
# 1          6925370027         2115077279   15264616
# 2          7707744797          951637071  298084239
# 3          5294925051          731897793     844748
# 4          4306968612          528552815    3159642
# 5          2073801567          577791589   50918760
# 6          2175218939          347276988   11038856
# 7          1139897981          183189121   24312894
# 8          1115954177          229931261    1308891
# 9          1083795424          221959720   19664150
# 10          945900736          162153778    6699008
# 11          820333554          279280479    5365672
# 12          943320953          100278565      99868
# 13          589796293          161684484     968166
# 14          630705096          104817034    7948720
# 15          554632707          177097132          0
# 16          563921523           92582081    5570891
# 17          416257051          138859651    8968932
# 18          408652888           59803277   31620332
# 19          393750947           91307741    2732190

# %% [markdown]
# **Table xx: Top 20 States and Flood Events by Number of Claims**

# %%
con.sql("""
    SELECT
        state,
        floodEvent,
        yearOfLoss,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    WHERE floodEvent NOT NULL
    GROUP BY ALL
    ORDER BY countClaims DESC
    LIMIT 20
""").df()
# Out:
#    state                   floodEvent  yearOfLoss  countClaims  \
# 0     LA            Hurricane Katrina        2005       176276
# 1     TX             Hurricane Harvey        2017        91872
# 2     NJ              Hurricane Sandy        2012        74983
# 3     NY              Hurricane Sandy        2012        57405
# 4     FL             Hurricane Helene        2024        54458
# 5     FL                Hurricane Ian        2022        47490
# 6     TX                Hurricane Ike        2008        44095
# 7     LA                     Flooding        1995        36820
# 8     LA     Mid-summer severe storms        2016        30018
# 9     FL               Hurricane Irma        2017        28756
# 10    TX       Tropical Storm Allison        2001        26821
# 11    FL             Hurricane Milton        2024        21448
# 12    FL              Hurricane Irene        1999        21192
# 13    MS            Hurricane Katrina        2005        19051
# 14    NJ              Hurricane Irene        2011        18125
# 15    LA                     Flooding        1980        17236
# 16    NJ  December Storm - Nor'easter        1992        16585
# 17    FL              Hurricane Wilma        2005        16557
# 18    NC           Hurricane Florence        2018        15337
# 19    NY              Hurricane Irene        2011        14744
#
#     paidTotalClaim  paidBuildingClaim  paidContentsClaim    paidICC
# 0      13347164644        10441743931         2721451049  183969663
# 1       9040370286         6912549831         2112555840   15264616
# 2       4372261883         3673280769          457640033  241341081
# 3       4215062163         3702376632          465410811   47274721
# 4       5781758403         5080129005          700784650     844748
# 5       4792735437         4265342788          524398008    2994642
# 6       2230307106         1723323896          481446923   25536286
# 7        594357775          442113752          152244023          0
# 8       2533534783         2175218939          347276988   11038856
# 9        985666540          834520911          145158635    5986994
# 10       978096837          723017851          250198245    4880741
# 11      1043689059          943310626          100278565      99868
# 12       117914566           86329238           31585328          0
# 13      2521512578         1910623703          558996059   51892816
# 14       599488993          497230608           96994208    5264178
# 15       103398787           72310263           31088525          0
# 16       179677100          147336659           32340441          0
# 17       358146723          302153010           54359773    1633940
# 18       637274421          541223398           89079169    6971854
# 19       348689416          305029723           41194756    2464936

# %% [markdown]
# **Table xx: Top 20 States and Flood Events by Total Paid Claims**

# %%
con.sql("""
    SELECT
        state,
        floodEvent,
        yearOfLoss,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    WHERE floodEvent NOT NULL
    GROUP BY ALL
    ORDER BY paidTotalClaim DESC
    LIMIT 20
""").df()
# Out:
#    state                floodEvent  yearOfLoss  countClaims  paidTotalClaim  \
# 0     LA         Hurricane Katrina        2005       176276     13347164644
# 1     TX          Hurricane Harvey        2017        91872      9040370286
# 2     FL          Hurricane Helene        2024        54458      5781758403
# 3     FL             Hurricane Ian        2022        47490      4792735437
# 4     NJ           Hurricane Sandy        2012        74983      4372261883
# 5     NY           Hurricane Sandy        2012        57405      4215062163
# 6     LA  Mid-summer severe storms        2016        30018      2533534783
# 7     MS         Hurricane Katrina        2005        19051      2521512578
# 8     TX             Hurricane Ike        2008        44095      2230307106
# 9     FL          Hurricane Milton        2024        21448      1043689059
# 10    FL            Hurricane Irma        2017        28756       985666540
# 11    TX    Tropical Storm Allison        2001        26821       978096837
# 12    FL            Hurricane Ivan        2004        12934       966741463
# 13    TX     Tropical Storm Imelda        2019        10937       752448943
# 14    LA             Hurricane Ida        2021        14676       689399171
# 15    NC        Hurricane Florence        2018        15337       637274421
# 16    NJ           Hurricane Irene        2011        18125       599488993
# 17    LA                  Flooding        1995        36820       594357775
# 18    LA           Hurricane Isaac        2012        13318       513274540
# 19    TX      Spring severe storms        2016         8414       472718247
#
#     paidBuildingClaim  paidContentsClaim    paidICC
# 0         10441743931         2721451049  183969663
# 1          6912549831         2112555840   15264616
# 2          5080129005          700784650     844748
# 3          4265342788          524398008    2994642
# 4          3673280769          457640033  241341081
# 5          3702376632          465410811   47274721
# 6          2175218939          347276988   11038856
# 7          1910623703          558996059   51892816
# 8          1723323896          481446923   25536286
# 9           943310626          100278565      99868
# 10          834520911          145158635    5986994
# 11          723017851          250198245    4880741
# 12          768189098          182722004   15830361
# 13          589796293          161684484     968166
# 14          557350031          131020181    1028959
# 15          541223398           89079169    6971854
# 16          497230608           96994208    5264178
# 17          442113752          152244023          0
# 18          375382324          129362462    8529754
# 19          389154552           82962228     601467

# %% [markdown]
# **Table xx: Top 20 Rated Flood Zones by Number of Claims**

# %%
con.sql("""
    SELECT
        ratedFloodZone as ratedFloodZone,
        COUNT(id) AS countClaims,
        ROUND(
            SUM(amountPaidOnBuildingClaim)
            + SUM(amountPaidOnContentsClaim)
            + SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidTotalClaim,  
        ROUND(SUM(amountPaidOnBuildingClaim), 0)::BIGINT AS paidBuildingClaim,
        ROUND(SUM(amountPaidOnContentsClaim), 0)::BIGINT AS paidContentsClaim, 
        ROUND(SUM(amountPaidOnIncreasedCostOfComplianceClaim), 0)::BIGINT AS paidICC
    FROM claims
    GROUP BY ratedFloodZone
    ORDER BY countClaims DESC
    LIMIT 20
""").df()
# Out:
#    ratedFloodZone  countClaims  paidTotalClaim  paidBuildingClaim  \
# 0              AE       934394     42224109737        35523442901
# 1               X       404262     13758371627        10656117320
# 2               A       201023      3245027249         2589229139
# 3               C       163811      2854901248         2120676642
# 4            None       139030       696659870          491536385
# 5               B       114982      3831518356         2840023155
# 6             A04        51801      2186540884         1801344331
# 7             A01        51360      1526374899         1189314596
# 8             A05        48584      1274257006         1058752273
# 9              VE        47839      1941278588         1729085731
# 10            A06        47083      1045114551          844649239
# 11            A08        45653      1455572800         1184903377
# 12            A07        43607      1150599787          939778433
# 13            A03        41867      1651513427         1338330551
# 14            A10        41171      1273694346          994009874
# 15            A02        31616       964383515          762429166
# 16            A11        30095       835934601          667558782
# 17            AHB        29762       293753797          218631030
# 18            A09        26684       794272088          609142433
# 19            A14        24295       703079232          539674249
#
#     paidContentsClaim    paidICC
# 0          6181434631  519232206
# 1          3073520010   28734297
# 2           618510548   37287562
# 3           724109225   10115382
# 4           205049316      74169
# 5           972658315   18836887
# 6           364556827   20639726
# 7           321004209   16056094
# 8           186583042   28921691
# 9           194118081   18074776
# 10          171603845   28861467
# 11          237464715   33204708
# 12          183930045   26891309
# 13          284758140   28424737
# 14          260802620   18881852
# 15          190227199   11727150
# 16          154482773   13893046
# 17           74950617     172150
# 18          167196033   17933621
# 19          153188379   10216604

# %% [markdown]
# From the Data Dictionary:
# >Formerly called floodZone. NFIP Flood Zone derived from the Flood Insurance Rate Map (FIRM) used to rate the insured property. A - Special Flood with no Base Flood Elevation on FIRM; AE, A1-A30 - Special Flood with Base Flood Elevation on FIRM; A99 - Special Flood with Protection Zone; AH, AHB* - Special Flood with Shallow Ponding; AO, AOB* - Special Flood with Sheet Flow; X, B - Moderate Flood from primary water source. Pockets of areas subject to drainage problems; X, C - Minimal Flood from primary water source. Pockets of areas subject to drainage problems; D - Possible Flood; V - Velocity Flood with no Base Flood Elevation on FIRM; VE, V1-V30 - Velocity Flood with Base Flood Elevation on FIRM; AE, VE, X - New zone designations used on new maps starting January 1, 1986, in lieu of A1-A30, V1-V30, and B and C; AR - A Special Flood Hazard Area that results from the decertification of a previously accredited flood protection system that is determined to be in the process of being restored to provide base flood protection; AR Dual Zones - (AR/AE, AR/A1-A30, AR/AH, AR/AO, AR/A) Areas subject to flooding from failure of the flood protection system (Zone AR) which also overlap an existing Special Flood Hazard Area as a dual zone; *AHB, AOB, ARE, ARH, ARO, and ARA are not risk zones shown on a map, but are acceptable values for rating purposes*

# %% [markdown]
# # Sample Workflow of Saving Files
# ## Saving Claims by State and Year of Loss

# %%
# sanity check with pandas
df = con.sql("""
    SELECT
        UPPER(state) AS state,
        yearOfLoss,
        COUNT(*) AS claims
    FROM claims 
    WHERE yearOfLoss >= 2009
    GROUP BY ALL
    ORDER BY state ASC, yearOfLoss ASC      
""").df()

df
# Out:
#     state  yearOfLoss  claims
# 0      AK        2009      17
# 1      AK        2010       2
# 2      AK        2011       7
# 3      AK        2012      66
# 4      AK        2013      46
# ..    ...         ...     ...
# 903    WY        2019      20
# 904    WY        2021       2
# 905    WY        2022       2
# 906    WY        2023      13
# 907    WY        2024       1
#
# [908 rows x 3 columns]

# %%
# write out as Parquet file
con.sql("""
    COPY (
        SELECT
            UPPER(state) AS state,
            yearOfLoss,
            COUNT(*) AS claims
        FROM claims 
        WHERE yearOfLoss >= 2009
        GROUP BY ALL
        ORDER BY state ASC, yearOfLoss ASC 
    )
    TO 'data/claims-state-year.parquet' (FORMAT 'parquet');
""")

# %ls data/
# Out:
# FimaNfipClaims.parquet       nfip-data.db
# FimaNfipPolicies.parquet     nfip.db
# claims-nyc-year.parquet      policies-nyc-year.parquet
# claims-state-year.parquet    policies-state-year.parquet
# claims.db                    policies.db

# %%
# sanity check
duckdb.sql("""
    SELECT *
    FROM 'data/claims-state-year.parquet'
    LIMIT 10
""")
# Out:
# ┌─────────┬────────────┬────────┐
# │  state  │ yearOfLoss │ claims │
# │ varchar │   int16    │ int64  │
# ├─────────┼────────────┼────────┤
# │ AK      │       2009 │     17 │
# │ AK      │       2010 │      2 │
# │ AK      │       2011 │      7 │
# │ AK      │       2012 │     66 │
# │ AK      │       2013 │     46 │
# │ AK      │       2014 │     22 │
# │ AK      │       2015 │      7 │
# │ AK      │       2016 │      8 │
# │ AK      │       2017 │      6 │
# │ AK      │       2018 │      1 │
# ├─────────┴────────────┴────────┤
# │ 10 rows             3 columns │
# └───────────────────────────────┘

# %%
# sanity check
duckdb.sql("""
    SELECT COUNT(*) AS count
    FROM 'data/claims-state-year.parquet'
""")
# Out:
# ┌───────┐
# │ count │
# │ int64 │
# ├───────┤
# │   908 │
# └───────┘

# %% [markdown]
# ## Saving Claims by New York City Counties (Boroughs) and Year of Loss

# %%
con.sql("""
    COPY (
        SELECT
            UPPER(state) AS state,
            countyCode,
            yearOfLoss,
            COUNT(*) AS claims
        FROM claims 
        WHERE yearOfLoss >= 2009
            AND countyCode IN ('36005', '36047', '36061', '36081', '36085')
        GROUP BY ALL
        ORDER BY countyCode ASC, yearOfLoss ASC
    )
    TO 'data/claims-nyc-year.parquet' (FORMAT 'parquet');
""")

# %ls data/
# Out:
# FimaNfipClaims.parquet       nfip-data.db
# FimaNfipPolicies.parquet     nfip.db
# claims-nyc-year.parquet      policies-nyc-year.parquet
# claims-state-year.parquet    policies-state-year.parquet
# claims.db                    policies.db

# %%
# sanity check
duckdb.sql("""
    SELECT *
    FROM 'data/claims-nyc-year.parquet'
    LIMIT 10
""")
# Out:
# ┌─────────┬────────────┬────────────┬────────┐
# │  state  │ countyCode │ yearOfLoss │ claims │
# │ varchar │  varchar   │   int16    │ int64  │
# ├─────────┼────────────┼────────────┼────────┤
# │ NY      │ 36005      │       2009 │      4 │
# │ NY      │ 36005      │       2010 │     91 │
# │ NY      │ 36005      │       2011 │    119 │
# │ NY      │ 36005      │       2012 │    547 │
# │ NY      │ 36005      │       2013 │      3 │
# │ NY      │ 36005      │       2014 │      8 │
# │ NY      │ 36005      │       2015 │      3 │
# │ NY      │ 36005      │       2016 │      2 │
# │ NY      │ 36005      │       2017 │      5 │
# │ NY      │ 36005      │       2018 │     18 │
# ├─────────┴────────────┴────────────┴────────┤
# │ 10 rows                          4 columns │
# └────────────────────────────────────────────┘

# %%
# sanity check
duckdb.sql("""
    SELECT COUNT(*) AS count
    FROM 'data/claims-nyc-year.parquet'
""")
# Out:
# ┌───────┐
# │ count │
# │ int64 │
# ├───────┤
# │    81 │
# └───────┘

# %%
# preview size of file
# !du -sh data/* | sort -rh
# Out:
#  11G	data/policies.db
# 3.2G	data/FimaNfipPolicies.parquet
# 2.9G	data/nfip-data.db
# 609M	data/claims.db
# 305M	data/nfip.db
# 194M	data/FimaNfipClaims.parquet
# 8.0K	data/policies-state-year.parquet
# 4.0K	data/policies-nyc-year.parquet
# 4.0K	data/claims-state-year.parquet
# 4.0K	data/claims-nyc-year.parquet

# %%
# close connection
con.close()
